# %% [markdown]
# <a href="https://colab.research.google.com/github/alvaromh16/Proyecto-IA-2-Trimestre/blob/main/Untitled14.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
dh=pd.read_csv('/content/rna_1.csv')

# %%
dh.head()
# Out:
#    Unnamed: 0  v_viento  humedad  presion  temperatura rain_tomorrow
# 0           0       4.0     73.0      NaN         20.3            No
# 1           1      15.0     68.0      NaN         12.0            No
# 2           2      13.0     56.0   1017.9         10.6           Yes
# 3           3      31.0     99.0   1010.4          8.5           Yes
# 4           4      17.0     66.0   1011.5         29.5           Yes

# %%
dh.shape
# Out:
# (39, 6)

# %%
dh.dtypes
# Out:
# Unnamed: 0         int64
# v_viento         float64
# humedad          float64
# presion          float64
# temperatura      float64
# rain_tomorrow     object
# dtype: object

# %%
dh.isnull().sum()
# Out:
# Unnamed: 0       0
# v_viento         0
# humedad          0
# presion          5
# temperatura      0
# rain_tomorrow    0
# dtype: int64

# %%
dh.isnull().sum().sum()
# Out:
# 5

# %%
sns.heatmap(dh.isnull())
# Out:
# <Axes: >

# %%
df_A=dh.dropna()
df_A
# Out:
#     Unnamed: 0  v_viento  humedad  presion  temperatura rain_tomorrow
# 2            2      13.0     56.0   1017.9         10.6           Yes
# 3            3      31.0     99.0   1010.4          8.5           Yes
# 4            4      17.0     66.0   1011.5         29.5           Yes
# 5            5      15.0     99.0   1022.3          9.4            No
# 6            6       6.0     91.0   1024.7          3.8            No
# 8            8      17.0     48.0   1016.1         24.8            No
# 9            9      19.0     53.0   1017.3         23.4            No
# 10          10      15.0     64.0   1004.6         11.1            No
# 11          11      22.0     55.0   1023.9         11.5            No
# 12          12      13.0     44.0   1008.9         24.1            No
# 13          13      19.0     84.0   1020.8          8.5            No
# 14          14      11.0     39.0   1018.0         24.8            No
# ...

# %%
df_A.replace('?',np.NaN,inplace=True)
# Out:
# <ipython-input-68-9bd738089c91>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_A.replace('?',np.NaN,inplace=True)

# %%
df_A=dh.dropna()

# %%
df_A.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 34 entries, 2 to 38
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0     34 non-null     int64
#  1   v_viento       34 non-null     float64
#  2   humedad        34 non-null     float64
#  3   presion        34 non-null     float64
#  4   temperatura    34 non-null     float64
#  5   rain_tomorrow  34 non-null     object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 1.9+ KB

# %%
sns.heatmap(df_A.isnull())
# Out:
# <Axes: >

# %%
dh_new=df_A.drop('Unnamed: 0',axis=1)

# %%
dh_new.head()
# Out:
#    v_viento  humedad  presion  temperatura rain_tomorrow
# 2      13.0     56.0   1017.9         10.6           Yes
# 3      31.0     99.0   1010.4          8.5           Yes
# 4      17.0     66.0   1011.5         29.5           Yes
# 5      15.0     99.0   1022.3          9.4            No
# 6       6.0     91.0   1024.7          3.8            No

# %%
dh_new_array=dh_new.to_numpy()
dh_new_array
# Out:
# array([[13.0, 56.0, 1017.9, 10.6, 'Yes'],
#        [31.0, 99.0, 1010.4, 8.5, 'Yes'],
#        [17.0, 66.0, 1011.5, 29.5, 'Yes'],
#        [15.0, 99.0, 1022.3, 9.4, 'No'],
#        [6.0, 91.0, 1024.7, 3.8, 'No'],
#        [17.0, 48.0, 1016.1, 24.8, 'No'],
#        [19.0, 53.0, 1017.3, 23.4, 'No'],
#        [15.0, 64.0, 1004.6, 11.1, 'No'],
#        [22.0, 55.0, 1023.9, 11.5, 'No'],
#        [13.0, 44.0, 1008.9, 24.1, 'No'],
#        [19.0, 84.0, 1020.8, 8.5, 'No'],
#        [11.0, 39.0, 1018.0, 24.8, 'No'],
#        [11.0, 56.0, 1016.4, 20.8, 'No'],
#        [13.0, 64.0, 1019.0, 25.4, 'Yes'],
#        [20.0, 97.0, 1017.5, 14.1, 'No'],
#        [11.0, 74.0, 1013.1, 26.4, 'No'],
#        [13.0, 58.0, 1022.7, 16.5, 'No'],
#        [0.0, 70.0, 1025.0, 15.8, 'No'],
#        [20.0, 47.0, 1018.6, 20.9, 'No'],
#        [0.0, 100.0, 1016.9, 1.5, 'No'],
#        [31.0, 54.0, 1013.5, 25.9, 'No'],
#        [13.0, 52.0, 1020.4, 15.4, 'No'],
#        [11.0, 81.0, 1014.5, 21.4, 'Yes'],
# ...

# %%
columna_y=df_A.rain_tomorrow
print(columna_y)
# Out:
# 2     Yes
# 3     Yes
# 4     Yes
# 5      No
# 6      No
# 8      No
# 9      No
# 10     No
# 11     No
# 12     No
# 13     No
# 14     No
# 15     No
# 16    Yes
# 17     No
# 18     No
# 19     No
# 20     No
# 21     No
# 22     No
# 23     No
# 24     No
# 25    Yes
# 27    Yes
# 28    Yes
# 29     No
# 30    Yes
# 31     No
# 32     No
# 33    Yes
# 35    Yes
# 36     No
# 37     No
# 38     No
# Name: rain_tomorrow, dtype: object

# %%
len('columna_y')
# Out:
# 9

# %%
x=df_A.iloc[:,1:5]

# %%
y=df_A.iloc[:,-1]

# %%
x_in=x.to_numpy()

# %%
y_out=y.to_numpy

# %%
sns.countplot(x='rain_tomorrow',data=df_A)
# Out:
# <Axes: xlabel='rain_tomorrow', ylabel='count'>

# %%
df_A.describe()
# Out:
#        Unnamed: 0  v_viento     humedad      presion  temperatura
# count   34.000000  34.00000   34.000000    34.000000    34.000000
# mean    19.794118  13.50000   70.117647  1018.047059    16.817647
# std     10.752813   7.02916   21.040746     5.414976     7.434664
# min      2.000000   0.00000   20.000000  1004.600000     1.500000
# 25%     11.250000  11.00000   55.250000  1014.825000    11.200000
# 50%     19.500000  13.00000   67.500000  1017.950000    16.450000
# 75%     28.750000  17.00000   89.250000  1022.600000    23.225000
# max     38.000000  31.00000  100.000000  1027.500000    29.500000

# %%
df_A_corr=df_A.corr()
fig, ax = plt.subplots(figsize=(8, 6))
sns.heatmap(df_A_corr, annot=True)
# Out:
# <ipython-input-83-1a807b4360df>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df_A_corr=df_A.corr()
# <Axes: >

# %%
sns.histplot(df_A['v_viento'], bins=10,kde=True)
plt.ylabel('frequencia'),plt.xlabel('v_viento m/s')
plt.title('Histograma variable v_viento')
plt.show()

# %%
sns.pairplot(df_A,hue='rain_tomorrow',palette='coolwarm')

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
print(scaler.fit(x_in))
x_inE=scaler .transform(x_in)
x_inE
# Out:
# MinMaxScaler()
# array([[0.41935484, 0.45      , 0.58078603, 0.325     ],
#        [1.        , 0.9875    , 0.25327511, 0.25      ],
#        [0.5483871 , 0.575     , 0.30131004, 1.        ],
#        [0.48387097, 0.9875    , 0.77292576, 0.28214286],
#        [0.19354839, 0.8875    , 0.87772926, 0.08214286],
#        [0.5483871 , 0.35      , 0.50218341, 0.83214286],
#        [0.61290323, 0.4125    , 0.55458515, 0.78214286],
#        [0.48387097, 0.55      , 0.        , 0.34285714],
#        [0.70967742, 0.4375    , 0.84279476, 0.35714286],
#        [0.41935484, 0.3       , 0.18777293, 0.80714286],
#        [0.61290323, 0.8       , 0.70742358, 0.25      ],
#        [0.35483871, 0.2375    , 0.58515284, 0.83214286],
#        [0.35483871, 0.45      , 0.51528384, 0.68928571],
#        [0.41935484, 0.55      , 0.62882096, 0.85357143],
#        [0.64516129, 0.9625    , 0.56331878, 0.45      ],
#        [0.35483871, 0.675     , 0.37117904, 0.88928571],
# ...

# %%
sns.boxplot(x_in)
# Out:
# <Axes: >

# %%
sns.boxplot(x_inE)
# Out:
# <Axes: >
